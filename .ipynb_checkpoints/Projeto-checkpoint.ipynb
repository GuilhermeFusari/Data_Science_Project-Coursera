# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
from sklearn.preprocessing import MinMaxScaler
data = pd.read_csv('Banknote-authentication-dataset-.csv')
data
# Out:
#            V1        V2
# 0     3.62160   8.66610
# 1     4.54590   8.16740
# 2     3.86600  -2.63830
# 3     3.45660   9.52280
# 4     0.32924  -4.45520
# ...       ...       ...
# 1367  0.40614   1.34920
# 1368 -1.38870  -4.87730
# 1369 -3.75030 -13.45860
# 1370 -3.56370  -8.38270
# 1371 -2.54190  -0.65804
#
# [1372 rows x 2 columns]

# %%
import matplotlib.patches as patches

# %%
obj_norm = MinMaxScaler().fit(data)

# %%
norm_data = obj_norm.transform(data)
norm_data = pd.DataFrame(norm_data)
norm_data.describe()
# Out:
#                  0            1
# count  1372.000000  1372.000000
# mean      0.539114     0.587301
# std       0.205003     0.219611
# min       0.000000     0.000000
# 25%       0.379977     0.451451
# 50%       0.543617     0.602168
# 75%       0.711304     0.770363
# max       1.000000     1.000000

# %%
column1 = norm_data[0]
column2 = norm_data[1]
x_mean = np.mean(column1)
y_mean = np.mean(column2)

# %%
mean = np.array([[x_mean],[y_mean]])
std_dev1 = np.std(column1)
std_dev2 = np.std(column2)
print(std_dev1, std_dev2)

# %%
ellipse = Ellipse((x_mean,y_mean),std_dev1*2,std_dev2*2, alpha = 0.25)
fig,graph = plt.subplots()
graph.scatter(x_mean, y_mean)

# %%
fig,graph = plt.subplots()
graph.scatter(column1, column2, alpha = 0.25)
graph.scatter(x_mean, y_mean)
graph.add_patch(ellipse)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16372\3574241685.py in <module>
#       2 graph.scatter(column1, column2, alpha = 0.25)
#       3 graph.scatter(x_mean, y_mean)
# ----> 4 graph.add_patch(ellipse)
#       5
#       6
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    2358         """
#    2359         self._deprecate_noninstance('add_patch', mpatches.Patch, p=p)
# -> 2360         self._set_artist_props(p)
#    2361         if p.get_clip_path() is None:
#    2362             p.set_clip_path(self.patch)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _set_artist_props(self, a)
#    1100     def _set_artist_props(self, a):
#    1101         """Set the boilerplate props for artists added to Axes."""
# -> 1102         a.set_figure(self.figure)
#    1103         if not a.is_transform_set():
#    1104             a.set_transform(self.transData)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in set_figure(self, fig)
#     738         # to more than one Axes
#     739         if self.figure is not None:
# --> 740             raise RuntimeError("Can not put single artist in "
#     741                                "more than one figure")
#     742         self.figure = fig
#
# RuntimeError: Can not put single artist in more than one figure
